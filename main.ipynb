# %%
import fitz  # PyMuPDF for PDF text extraction
import google.generativeai as genai

# Configure the API key
genai.configure(api_key="")

def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = "\n".join([page.get_text("text") for page in doc])
    return text

def query_gemini(prompt, context):
    model = genai.GenerativeModel("gemini-2.0-flash")
    response = model.generate_content(f"Context: {context}\n\nQuestion: {prompt}")
    return response.text

def main():
    pdf_path = r"cnn.pdf" 
    text = extract_text_from_pdf(pdf_path)

    print("Hey there, Ask your question:")
    while True:
        question = input("> ")
        if question.lower() in ["exit", "quit"]:
            break
        answer = query_gemini(question, text)
        print("\nAnswer:", answer)

if __name__ == "__main__":
    main()
# Out:
# Hey there, Ask your question:
#
# Answer: Based on the provided slides, here's what we can say about mRNA:
#
# *   **Function:** mRNA (messenger RNA) serves as the template for translation into a polypeptide (protein).
# *   **Organization:** In bacteria, mRNA has specific sequences for initiation and termination of translation, as well as the coding region.
# *   **Polarity:** The 5'-to-3' direction in mRNA corresponds to the N-to-C direction in the resulting polypeptide.
# *   **Lifespan:** mRNA's lifespan varies, lasting from minutes in viruses/E. coli to hours or weeks in yeast/humans.
# *   **Genetic Code:** mRNA carries the genetic code in the form of codons (triplets of nucleotides) that specify the sequence of amino acids in a protein.
# *   **Eukaryotic mRNA Precursors:** In eukaryotes, pre-mRNA molecules (hnRNA) are processed to generate mature mRNAs.
#
#
# Answer: Okay, let's break down tRNA in detail, drawing from the provided information and expanding on it.
#
# **Transfer RNA (tRNA): The Adaptor Molecule of Translation**
#
# tRNA is a crucial type of RNA molecule that serves as the "adaptor" or "interpreter" during protein synthesis (translation). It bridges the gap between the genetic code (mRNA codons) and the amino acid building blocks of proteins. Here's a comprehensive look:
#
# **1. Discovery and Early Understanding:**
#
# *   **Landmark Research:** Paul C. Zamecnik and his team made a breakthrough by developing cell-free extracts able to produce proteins from amino acid precursors using RNA templates. Using radiolabeled amino acids and ultracentrifugation, they traced how amino acids are attached to tRNA molecules before incorporation into proteins.
# *   **Crick's Adaptor Hypothesis:** Francis Crick proposed the "Adaptor Hypothesis," suggesting the existence of a molecule (tRNA) that could recognize both mRNA codons and specific amino acids. This hypothesis was confirmed with the discovery of tRNA.
#
# **2. Structure: A Unique and Conserved Design**
#
# *   **Size and Abundance:** tRNA molecules are relatively small, typically ranging from 74 to 95 nucleotides in length. They represent approximately 10-15% of all cellular RNA.
# *   **Single-Stranded:** tRNAs are single-stranded RNA molecules, but they fold into a complex three-dimensional structure through extensive intramolecular base pairing.
# *   **Secondary Structure: The Cloverleaf Model:**
#     *   The classic representation of tRNA is the "cloverleaf" structure.
#     *   It consists of several stem-loop regions and an acceptor stem, where the amino acid is attached.
#     *   The specific regions are:
#         *   **Acceptor Stem:**  Located at the 3' end of the tRNA molecule. This stem typically contains 7 base pairs and terminates in a single-stranded CCA sequence. The 3'-OH of the terminal adenosine in the CCA sequence is where the amino acid is attached.
#         *   **D-arm:**  Contains the modified base dihydrouridine (UH2).
#         *   **Anticodon Arm:**  Contains the anticodon, a three-nucleotide sequence that is complementary to a specific mRNA codon. This is crucial for decoding the genetic message.
#         *   **TψC Arm:**  Contains the sequence TψC (ribothymidine, pseudouridine, and cytosine). This arm helps in binding the tRNA to the ribosome.
#
# *   **Tertiary Structure: L-Shape:** The cloverleaf folds into a compact L-shaped tertiary structure. This L-shape is critical for the tRNA's interactions with ribosomes and other molecules involved in translation.
# *   **Modified Bases:** tRNA contains many unusual or modified nucleosides (e.g., pseudouridine (ψ), ribothymidine (T), dihydrouridine (UH2), inosine (I), methylguanosine (mG)). These modifications:
#     *   Contribute to the stable folding of the tRNA.
#     *   Enhance tRNA's ability to interact with ribosomes.
#     *   Improve the accuracy of codon recognition.
#
# **3. Function: Delivering Amino Acids**
#
# *   **Aminoacylation:** The most important function of tRNA is to carry a specific amino acid to the ribosome for protein synthesis. This process, called "aminoacylation" or "charging," is catalyzed by enzymes called aminoacyl-tRNA synthetases.
#     *   **Specificity:** Each aminoacyl-tRNA synthetase is highly specific for a particular amino acid and its corresponding tRNA(s).  There's typically one synthetase for each of the 20 amino acids.
#     *   **Ester Bond Formation:** The aminoacyl-tRNA synthetase attaches the amino acid to the 3'-OH of the terminal adenosine residue on the acceptor stem of the tRNA via an ester bond. The carboxyl group (COOH) of the amino acid forms the ester linkage with the 3'OH of the tRNA.
#     *   **Energy Requirement:** Aminoacylation requires ATP, making it an energy-dependent process.
# *   **Codon Recognition:**  During translation, the anticodon of the tRNA base-pairs with the complementary codon on the mRNA. This ensures that the correct amino acid is added to the growing polypeptide chain.
# *   **Wobble Hypothesis:** Francis Crick proposed the "wobble hypothesis" to explain how a single tRNA can recognize more than one codon. The wobble hypothesis states that the third base in the codon (the 3' base) and the first base in the anticodon (the 5' base) are not as spatially confined as the other bases, so they are not as stringent in their base-pairing. This allows for some non-standard base pairing at the third position, leading to degeneracy in the genetic code.
#     *   **Examples of Wobble Base Pairs:**
#         *   Guanine (G) in the anticodon can pair with uracil (U) or cytosine (C) in the codon.
#         *   Inosine (I) in the anticodon can pair with uracil (U), cytosine (C), or adenine (A) in the codon.
#
# **4. Diversity and Isoaccepting tRNAs:**
#
# *   **Multiple tRNAs for Some Amino Acids:** Because the genetic code is degenerate (multiple codons can code for the same amino acid), cells often have multiple different tRNAs that carry the same amino acid. These are called "isoaccepting tRNAs."
# *   **Regulation:** The abundance of different tRNA species can vary between cells and under different growth conditions, suggesting that tRNA availability may play a role in regulating translation.
#
# **In Summary:**
#
# tRNA is essential for accurately translating the genetic code into proteins. Its unique structure, aminoacylation mechanism, and ability to recognize codons (sometimes with wobble) ensure that the correct amino acids are incorporated into the growing polypeptide chain, driving protein synthesis. The role of tRNA is a fundamental aspect of molecular biology.

# %%
import fitz  # PyMuPDF for PDF text extraction
import google.generativeai as genai

# Configure Gemini API Key
genai.configure(api_key="AIzaSyBrlZUjN8OH-_irwEfYV9c6mOjnPsVhkaU")  # Replace with your actual API key

def extract_text_from_pdf(pdf_path):
    """Extracts text from a PDF along with page numbers."""
    doc = fitz.open(pdf_path)
    extracted_data = []

    for page_num, page in enumerate(doc, start=1):
        text = page.get_text("text").strip()
        if text:
            extracted_data.append(f"(Page {page_num}):\n{text}")

    return "\n\n".join(extracted_data)  # Structured with page references

def query_gemini(text, question):
    """Queries Gemini LLM and asks it to return relevant page numbers."""
    model = genai.GenerativeModel("gemini-2.0-flash")
    
    prompt = (
        "You are an AI assistant extracting knowledge from a document. "
        "Answer the user's question using the given context, and specify which page(s) the answer comes from.\n\n"
        f"Context:\n{text}\n\nUser Question: {question}\n\n"
        "Please include the page numbers where the relevant information is found."
    )

    response = model.generate_content(prompt)
    return response.text

def main():
    pdf_path = "cnn.pdf"  # Replace with your PDF file
    text = extract_text_from_pdf(pdf_path)

    print("PDF Loaded. Ask your question:")
    while True:
        question = input("> ")
        if question.lower() in ["exit", "quit"]:
            break

        response = query_gemini(text, question)
        print("\nAnswer:", response)

if __name__ == "__main__":
    main()
# Out:
# PDF Loaded. Ask your question:
